# %%
import test_utility
import os

ts1 = []
for filename in sorted(os.listdir("/home/tom/tesi/MCSHeuristicCpp/test_results/total_similarity_H1/")):
    tt = test_utility.load_test("/home/tom/tesi/MCSHeuristicCpp/test_results/total_similarity_H1/" + filename)
    ts1.append(tt)

ts2 = []
for filename in sorted(os.listdir("/home/tom/tesi/MCSHeuristicCpp/test_results/total_similarity_H2/")):
    tt = test_utility.load_test("/home/tom/tesi/MCSHeuristicCpp/test_results/total_similarity_H2/" + filename)
    ts2.append(tt)

ts3 = []
for filename in sorted(os.listdir("/home/tom/tesi/MCSHeuristicCpp/test_results/total_similarity_H3/")):
    tt = test_utility.load_test("/home/tom/tesi/MCSHeuristicCpp/test_results/total_similarity_H3/" + filename)
    ts3.append(tt)

ts4 = []
for filename in sorted(os.listdir("/home/tom/tesi/MCSHeuristicCpp/test_results/total_similarity_H4/")):
    tt = test_utility.load_test("/home/tom/tesi/MCSHeuristicCpp/test_results/total_similarity_H4/" + filename)
    ts4.append(tt)

ts5 = []
for filename in sorted(os.listdir("/home/tom/tesi/MCSHeuristicCpp/test_results/total_similarity_H5/")):
    tt = test_utility.load_test("/home/tom/tesi/MCSHeuristicCpp/test_results/total_similarity_H5/" + filename)
    ts5.append(tt)

ts6 = []
for filename in sorted(os.listdir("/home/tom/tesi/MCSHeuristicCpp/test_results/total_similarity_H6/")):
    tt = test_utility.load_test("/home/tom/tesi/MCSHeuristicCpp/test_results/total_similarity_H6/" + filename)
    ts6.append(tt)

ts7 = []
for filename in sorted(os.listdir("/home/tom/tesi/MCSHeuristicCpp/test_results/total_similarity_H7/")):
    tt = test_utility.load_test("/home/tom/tesi/MCSHeuristicCpp/test_results/total_similarity_H7/" + filename)
    ts7.append(tt)

ts8 = []
for filename in sorted(os.listdir("/home/tom/tesi/MCSHeuristicCpp/test_results/total_similarity_H8/")):
    tt = test_utility.load_test("/home/tom/tesi/MCSHeuristicCpp/test_results/total_similarity_H8/" + filename)
    ts8.append(tt)

n1 = []
for filename in sorted(os.listdir("/home/tom/tesi/MCSHeuristicCpp/test_results/norm_H1/")):
    tt = test_utility.load_test("/home/tom/tesi/MCSHeuristicCpp/test_results/norm_H1/" + filename)
    n1.append(tt)

n2 = []
for filename in sorted(os.listdir("/home/tom/tesi/MCSHeuristicCpp/test_results/norm_H2/")):
    tt = test_utility.load_test("/home/tom/tesi/MCSHeuristicCpp/test_results/norm_H2/" + filename)
    n2.append(tt)

n3 = []
for filename in sorted(os.listdir("/home/tom/tesi/MCSHeuristicCpp/test_results/norm_H3/")):
    tt = test_utility.load_test("/home/tom/tesi/MCSHeuristicCpp/test_results/norm_H3/" + filename)
    n3.append(tt)

n4 = []
for filename in sorted(os.listdir("/home/tom/tesi/MCSHeuristicCpp/test_results/norm_H4/")):
    tt = test_utility.load_test("/home/tom/tesi/MCSHeuristicCpp/test_results/norm_H4/" + filename)
    n4.append(tt)

n5 = []
for filename in sorted(os.listdir("/home/tom/tesi/MCSHeuristicCpp/test_results/norm_H5/")):
    tt = test_utility.load_test("/home/tom/tesi/MCSHeuristicCpp/test_results/norm_H5/" + filename)
    n5.append(tt)

n6 = []
for filename in sorted(os.listdir("/home/tom/tesi/MCSHeuristicCpp/test_results/norm_H6/")):
    tt = test_utility.load_test("/home/tom/tesi/MCSHeuristicCpp/test_results/norm_H6/" + filename)
    n6.append(tt)

n7 = []
for filename in sorted(os.listdir("/home/tom/tesi/MCSHeuristicCpp/test_results/norm_H7/")):
    tt = test_utility.load_test("/home/tom/tesi/MCSHeuristicCpp/test_results/norm_H7/" + filename)
    n7.append(tt)

n8 = []
for filename in sorted(os.listdir("/home/tom/tesi/MCSHeuristicCpp/test_results/norm_H8/")):
    tt = test_utility.load_test("/home/tom/tesi/MCSHeuristicCpp/test_results/norm_H8/" + filename)
    n8.append(tt)

mc = []
for filename in sorted(os.listdir("/home/tom/tesi/MCSHeuristicCpp/test_results/classic/")):
    tt = test_utility.load_test("/home/tom/tesi/MCSHeuristicCpp/test_results/classic/" + filename)
    mc.append(tt)

rl = []
for filename in sorted(os.listdir("/home/tom/tesi/MCSHeuristicCpp/test_results/RL/")):
    tt = test_utility.load_test("/home/tom/tesi/MCSHeuristicCpp/test_results/RL/" + filename)
    rl.append(tt)

def print_test(t1, t2):
   print("test name:", t1.test_description[0])
   print("test name2: ", t2.test_description[0])
   print("h1: ", t1.milestones[-1][0], "found in ", t1.milestones[-1][1], "recursions", " -- time: ", t1.total_time)
   print("mc: ", t2.milestones[-1][0], "found in ", t2.milestones[-1][1], "recursions", "-- time: ", t2.total_time)

def compare_h(heuristic1TestResult, heuristic2TestResult):
    h1Score = 0
    mcScore = 0
    tie = 0
    fails = []

    size_classic = 0
    size_other = 0
    for t1 in heuristic1TestResult:
      for t2 in heuristic2TestResult:
        if t1.test_description[0] == t2.test_description[0]:
          #print_test(t1, t2)
          if t1.milestones[-1][0] > t2.milestones[-1][0]:
            h1Score += 1
            # print("H won")
          elif t1.milestones[-1][0] < t2.milestones[-1][0]:
            mcScore += 1
            # print("Mc Won")
            fails.append(t2)
          elif t1.milestones[-1][1] > t2.milestones[-1][1]:
            mcScore += 1
            # print("Mc Won")
            fails.append(t2)
          elif t1.milestones[-1][1] < t2.milestones[-1][1]:
            h1Score += 1
            # print("H Won")
          else: 
            tie += 1
            fails.append(t2)

    # print("hscore: ", h1Score)
    # print("McSplit: ", mcScore)
    # print("Ties: ", tie)
    # print("")
    return fails, h1Score

import matplotlib.pyplot as plt
import math

test = 7
print(len(mc[test].solution))
plt.plot([math.log(y[1], 10) for y in ts3[test].milestones], [x[0] for x in ts3[test].milestones], 'ro-', label = "CSS k=3", alpha = 0.5)
plt.plot([math.log(y[1], 10) for y in mc[test].milestones], [x[0] for x in mc[test].milestones], 'bo-', label = "McSplit", alpha = 0.5)
plt.legend(loc="lower right")
plt.xlabel("Log(#Recursions)")
plt.ylabel("Solution Size")
plt.grid()
plt.show()
# Out:
# 47

# %%
# fails, s1 = compare_h(ts1, mc)
# print(len(fails), 50 - len(fails))

fails, s1 = compare_h(ts3, mc)
print(len(fails),  s1)

fails, s2 = compare_h(ts4, fails)
print(len(fails), 50 - len(fails))

fails, s2 = compare_h(ts1, fails)
print(len(fails), 50 - len(fails))

fails, s2 = compare_h(ts6, fails)
print(len(fails), 50 - len(fails))

# fails, s2 = compare_h(n5, fails)
# print(len(fails), 50 - len(fails))

# fails, s2 = compare_h(n6, fails)
# print(len(fails), 50 - len(fails))

# fails, s2 = compare_h(n7, fails)
# print(len(fails), 50 - len(fails))

# fails, s2 = compare_h(n8, fails)
# print(len(fails), 50 - len(fails))
# Out:
# 13 36
# 8 42
# 7 43
# 6 44
